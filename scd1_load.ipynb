# %%
pip install boto3 yml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting boto3
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/4d/2f/65009a8d274cd9c7211807c1a07cce17203ffe76368e3ebc4ca03a7b79de/boto3-1.40.69-py3-none-any.whl.metadata
#   Using cached boto3-1.40.69-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: yml in ./.local/lib/python3.11/site-packages (0.0.1)
# Collecting botocore<1.41.0,>=1.40.69 (from boto3)
#   Obtaining dependency information for botocore<1.41.0,>=1.40.69 from https://files.pythonhosted.org/packages/61/d6/bf2b91d4a92af6ee70e0689913414463a48cf51c0fc855c98b94bde8e7f3/botocore-1.40.69-py3-none-any.whl.metadata
#   Using cached botocore-1.40.69-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from boto3) (0.10.0)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3)
#   Obtaining dependency information for s3transfer<0.15.0,>=0.14.0 from https://files.pythonhosted.org/packages/48/f0/ae7ca09223a81a1d890b2557186ea015f6e0502e9b8cb8e1813f1d8cfa4e/s3transfer-0.14.0-py3-none-any.whl.metadata
#   Using cached s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (1.26.16)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.69->boto3) (1.16.0)
# Using cached boto3-1.40.69-py3-none-any.whl (139 kB)
# Using cached botocore-1.40.69-py3-none-any.whl (14.1 MB)
# Using cached s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Installing collected packages: botocore, s3transfer, boto3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.5.0 requires botocore<1.29.77,>=1.29.76, but you have botocore 1.40.69 which is incompatible.
# Successfully installed boto3-1.40.69 botocore-1.40.69 s3transfer-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import yaml

with open('aws_creds.yml', 'r') as file:
    aws_credentials = yaml.safe_load(file)

# Extract credentials from YAML
aws_access_key_id = aws_credentials['aws_access_key_id']
aws_secret_access_key = aws_credentials['aws_secret_access_key']
aws_region_name = aws_credentials['aws_region_name']

# Initialize a session using AWS credentials
session = boto3.Session(
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=aws_region_name
)

#Update the below variables values with your details
file_name = 'customer_change_data.csv'
bucket_name = 'sd-scd1'
folder_name = 'data'

# Create an S3 client
s3_client = session.client('s3')
try: 
    # Upload file in S3
    s3_client.upload_file( 
    Filename =file_name, 
    Bucket=bucket_name, 
    Key=folder_name + '/' + file_name
    )
    print(file_name + " is uploaded sucessfully")

except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# customer_change_data.csv is uploaded sucessfully
